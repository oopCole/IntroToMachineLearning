# %% [markdown]
# <a href="https://colab.research.google.com/github/oopCole/IntroToMachineLearning/blob/main/CMPD%20Crime%20Statistics/Data%20Manipulation/NIBRS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

NIBRS = pd.read_csv('NIBRS_Code.csv')

print('First 5 rows of NIBRS DataFrame:')
display(NIBRS.head())

print('\nInformation about NIBRS DataFrame:')
NIBRS.info()

print('\nMissing values in NIBRS DataFrame:')
display(NIBRS.isnull().sum())
# Out:
# First 5 rows of NIBRS DataFrame:
#   Offense Code HIGHEST_NIBRS_DESCRIPTION Crime Against
# 0          200                     Arson      Property
# 1          13A        Aggravated Assault        Person
# 2          13B            Simple Assault        Person
# 3          13C              Intimidation        Person
# 4          510                   Bribery      Property
# Information about NIBRS DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Offense Code               49 non-null     object
#  1   HIGHEST_NIBRS_DESCRIPTION  49 non-null     object
#  2   Crime Against              49 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB
#
# Missing values in NIBRS DataFrame:
# Offense Code                 0
# HIGHEST_NIBRS_DESCRIPTION    0
# Crime Against                0
# ...

# %%
display(NIBRS)
# Out:
#    Offense Code                   HIGHEST_NIBRS_DESCRIPTION  \
# 0           200                                       Arson
# 1           13A                          Aggravated Assault
# 2           13B                              Simple Assault
# 3           13C                                Intimidation
# 4           510                                     Bribery
# 5           220                                Burglary/B&E
# 6           250                      Counterfeiting/Forgery
# 7           290                Damage/Vandalism Of Property
# 8           35A                    Drug/Narcotic Violations
# 9           35B                   Drug Equipment Violations
# 10          270                                Embezzlement
# 11          210                         Extortion/Blackmail
# 12          26A                     False Pretenses/Swindle
# 13          26B          Credit Card/Automated Teller Fraud
# 14          26C                               Impersonation
# ...

# %%
print('\nNumber of unique values in each column:')
for col in NIBRS.columns:
    print(f"{col}: {NIBRS[col].nunique()} unique values")
# Out:
# Number of unique values in each column:
# Offense Code: 49 unique values
# HIGHEST_NIBRS_DESCRIPTION: 49 unique values
# Crime Against: 6 unique values
