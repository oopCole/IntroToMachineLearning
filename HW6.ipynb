# %% [markdown]
# <a href="https://colab.research.google.com/github/oopCole/IntroToMachineLearning/blob/main/HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from tensorflow import keras
from keras import layers, models

# %% [markdown]
# Problem 1

# %%
# diabetes dataset from my github
dataFrame = pd.read_csv('https://raw.githubusercontent.com/oopCole/IntroToMachineLearning/refs/heads/main/diabetes.csv')

print(dataFrame.head())
print(dataFrame.info())
print(dataFrame.isnull().sum())

xFeatures = dataFrame.drop('Outcome', axis=1)
yTarget = dataFrame['Outcome']

# 20/80 split
xTrain, xVal, yTrain, yVal = train_test_split(xFeatures, yTarget, test_size=0.2, random_state=42, stratify=yTarget)

scaler = StandardScaler()
xTrainScaled = scaler.fit_transform(xTrain)
xValScaled = scaler.transform(xVal)

# 4 hidden layers
neuralModel = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(xTrainScaled.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

neuralModel.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print(neuralModel.summary())

earlyStopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

historyObject = neuralModel.fit(
    xTrainScaled, yTrain,
    epochs=100,
    batch_size=32,
    validation_data=(xValScaled, yVal),
    callbacks=[earlyStopping],
    verbose=1
)

# plot
plt.figure(figsize=(9, 4))

plt.subplot(1, 2, 1)
plt.plot(historyObject.history['loss'], label='Training Loss')
plt.plot(historyObject.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(historyObject.history['accuracy'], label='Training Accuracy')
plt.plot(historyObject.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.grid(True)

plt.tight_layout()
plt.show()

# predictions
yPredProba = neuralModel.predict(xValScaled)
yPredNN = (yPredProba > 0.5).astype(int).flatten()

nnAccuracy = accuracy_score(yVal, yPredNN)
nnPrecision = precision_score(yVal, yPredNN)
nnRecall = recall_score(yVal, yPredNN)
nnF1 = f1_score(yVal, yPredNN)

print("Neural Network Performance:")
print(f"Accuracy: {nnAccuracy:.4f}")
print(f"Precision: {nnPrecision:.4f}")
print(f"Recall: {nnRecall:.4f}")
print(f"F1 Score: {nnF1:.4f}")

# train logistic
logisticModel = LogisticRegression(max_iter=1000, random_state=42)
logisticModel.fit(xTrainScaled, yTrain)
yPredLR = logisticModel.predict(xValScaled)

lrAccuracy = accuracy_score(yVal, yPredLR)
lrPrecision = precision_score(yVal, yPredLR)
lrRecall = recall_score(yVal, yPredLR)
lrF1 = f1_score(yVal, yPredLR)

print("\nLogistic Regression Performance:")
print(f"Accuracy: {lrAccuracy:.4f}")
print(f"Precision: {lrPrecision:.4f}")
print(f"Recall: {lrRecall:.4f}")
print(f"F1 Score: {lrF1:.4f}")

# train support
svmModel = SVC(kernel='rbf', random_state=42)
svmModel.fit(xTrainScaled, yTrain)
yPredSVM = svmModel.predict(xValScaled)

svmAccuracy = accuracy_score(yVal, yPredSVM)
svmPrecision = precision_score(yVal, yPredSVM)
svmRecall = recall_score(yVal, yPredSVM)
svmF1 = f1_score(yVal, yPredSVM)

print("\nSupport Vector Machine Performance:")
print(f"Accuracy: {svmAccuracy:.4f}")
print(f"Precision: {svmPrecision:.4f}")
print(f"Recall: {svmRecall:.4f}")
print(f"F1 Score: {svmF1:.4f}")

comparisonData = {
    'Model': ['Neural Network', 'Logistic Regression', 'SVM'],
    'Accuracy': [nnAccuracy, lrAccuracy, svmAccuracy],
    'Precision': [nnPrecision, lrPrecision, svmPrecision],
    'Recall': [nnRecall, lrRecall, svmRecall],
    'F1 Score': [nnF1, lrF1, svmF1]
}

comparisonDf = pd.DataFrame(comparisonData)
print("\nModel Comparison:")
print(comparisonDf.to_string(index=False))

# bar chart of each model
metricsToPlot = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
xPositions = np.arange(len(metricsToPlot))
barWidth = 0.25

plt.figure(figsize=(8, 4))
plt.bar(xPositions - barWidth, [nnAccuracy, nnPrecision, nnRecall, nnF1], barWidth, label='Neural Network')
plt.bar(xPositions, [lrAccuracy, lrPrecision, lrRecall, lrF1], barWidth, label='Logistic Regression')
plt.bar(xPositions + barWidth, [svmAccuracy, svmPrecision, svmRecall, svmF1], barWidth, label='SVM')

plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Model Performance Comparison')
plt.xticks(xPositions, metricsToPlot)
plt.legend()
plt.ylim([0, 1])
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_75 (Dense)                │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_79 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,329 (13.00 KB)
#  Trainable params: 3,329 (13.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.6621 - loss: 0.6780 - val_accuracy: 0.6818 - val_loss: 0.6249
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6604 - loss: 0.6385 - val_accuracy: 0.6688 - val_loss: 0.5853
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6914 - loss: 0.5861 - val_accuracy: 0.6688 - val_loss: 0.5519
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6599 - loss: 0.5743 - val_accuracy: 0.7013 - val_loss: 0.5274
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6964 - loss: 0.5468 - val_accuracy: 0.7078 - val_loss: 0.5180
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7039 - loss: 0.5181 - val_accuracy: 0.7273 - val_loss: 0.5125
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7413 - loss: 0.5109 - val_accuracy: 0.7143 - val_loss: 0.5092
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7251 - loss: 0.4969 - val_accuracy: 0.7208 - val_loss: 0.5045
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7638 - loss: 0.5106 - val_accuracy: 0.7273 - val_loss: 0.5031
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7426 - loss: 0.5071 - val_accuracy: 0.7078 - val_loss: 0.5018
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7625 - loss: 0.4983 - val_accuracy: 0.7273 - val_loss: 0.4984
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7524 - loss: 0.5011 - val_accuracy: 0.7273 - val_loss: 0.4964
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7480 - loss: 0.5169 - val_accuracy: 0.7273 - val_loss: 0.4982
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7468 - loss: 0.4835 - val_accuracy: 0.7143 - val_loss: 0.5013
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7813 - loss: 0.4667 - val_accuracy: 0.7273 - val_loss: 0.5047
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7592 - loss: 0.4943 - val_accuracy: 0.7273 - val_loss: 0.5066
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7894 - loss: 0.4558 - val_accuracy: 0.7273 - val_loss: 0.5063
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7444 - loss: 0.4960 - val_accuracy: 0.7338 - val_loss: 0.5048
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7864 - loss: 0.4716 - val_accuracy: 0.7338 - val_loss: 0.5082
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7829 - loss: 0.4474 - val_accuracy: 0.7338 - val_loss: 0.5075
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7532 - loss: 0.4822 - val_accuracy: 0.7468 - val_loss: 0.5077
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8105 - loss: 0.4531 - val_accuracy: 0.7338 - val_loss: 0.5075
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7641 - loss: 0.4949 - val_accuracy: 0.7338 - val_loss: 0.5051
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7861 - loss: 0.4605 - val_accuracy: 0.7403 - val_loss: 0.5098
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7796 - loss: 0.4666 - val_accuracy: 0.7208 - val_loss: 0.5109
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7926 - loss: 0.4856 - val_accuracy: 0.7338 - val_loss: 0.5111
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7554 - loss: 0.4893 - val_accuracy: 0.7338 - val_loss: 0.5137
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Neural Network Performance:
# Accuracy: 0.7273
# Precision: 0.6111
# Recall: 0.6111
# F1 Score: 0.6111
#
# Logistic Regression Performance:
# Accuracy: 0.7143
# Precision: 0.6087
# Recall: 0.5185
# F1 Score: 0.5600
#
# Support Vector Machine Performance:
# Accuracy: 0.7532
# Precision: 0.6600
# Recall: 0.6111
# F1 Score: 0.6346
#
# Model Comparison:
#               Model  Accuracy  Precision   Recall  F1 Score
#      Neural Network  0.727273   0.611111 0.611111  0.611111
# Logistic Regression  0.714286   0.608696 0.518519  0.560000
#                 SVM  0.753247   0.660000 0.611111  0.634615

# %% [markdown]
# Problem 2

# %%
cancer = load_breast_cancer()

X_c, y_c = cancer.data, cancer.target
X_train_c, X_val_c, y_train_c, y_val_c = train_test_split(X_c, y_c, test_size=0.2, random_state=42, stratify=y_c)
scaler_c = StandardScaler().fit(X_train_c)
X_train_c_s = scaler_c.transform(X_train_c)
X_val_c_s = scaler_c.transform(X_val_c)

model_c = models.Sequential([
    layers.Input(shape=(X_train_c_s.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model_c.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist_c = model_c.fit(X_train_c_s, y_train_c, validation_data=(X_val_c_s, y_val_c), epochs=60, batch_size=16)
plot_loss(hist_c, "Breast Cancer - MLP Keras")
y_pred_c = (model_c.predict(X_val_c_s).ravel() >= 0.5).astype(int)

print("Cancer MLP metrics:", metrics_from_preds(y_val_c, y_pred_c))
print("Logistic:", metrics_from_preds(y_val_c, LogisticRegression(max_iter=5000).fit(X_train_c_s, y_train_c).predict(X_val_c_s)))
print("SVM:", metrics_from_preds(y_val_c, SVC().fit(X_train_c_s, y_train_c).predict(X_val_c_s)))
# Out:
# Epoch 1/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.6965 - loss: 0.5550 - val_accuracy: 0.9561 - val_loss: 0.1830
# Epoch 2/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9578 - loss: 0.1329 - val_accuracy: 0.9561 - val_loss: 0.0983
# Epoch 3/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9870 - loss: 0.0574 - val_accuracy: 0.9649 - val_loss: 0.0876
# Epoch 4/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9836 - loss: 0.0559 - val_accuracy: 0.9561 - val_loss: 0.0821
# Epoch 5/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9900 - loss: 0.0393 - val_accuracy: 0.9561 - val_loss: 0.0787
# Epoch 6/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9966 - loss: 0.0280 - val_accuracy: 0.9561 - val_loss: 0.0826
# Epoch 7/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0370 - val_accuracy: 0.9561 - val_loss: 0.0757
# Epoch 8/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9950 - loss: 0.0259 - val_accuracy: 0.9561 - val_loss: 0.0836
# Epoch 9/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9960 - loss: 0.0258 - val_accuracy: 0.9561 - val_loss: 0.0809
# Epoch 10/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - loss: 0.0137 - val_accuracy: 0.9561 - val_loss: 0.0873
# Epoch 11/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9970 - loss: 0.0127 - val_accuracy: 0.9561 - val_loss: 0.1011
# Epoch 12/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9991 - loss: 0.0127 - val_accuracy: 0.9649 - val_loss: 0.0817
# Epoch 13/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9970 - loss: 0.0079 - val_accuracy: 0.9561 - val_loss: 0.1162
# Epoch 14/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9994 - loss: 0.0115 - val_accuracy: 0.9649 - val_loss: 0.0963
# Epoch 15/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9995 - loss: 0.0093 - val_accuracy: 0.9649 - val_loss: 0.0934
# Epoch 16/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9903 - loss: 0.0128 - val_accuracy: 0.9561 - val_loss: 0.1220
# Epoch 17/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9968 - loss: 0.0064 - val_accuracy: 0.9561 - val_loss: 0.1040
# Epoch 18/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9911 - loss: 0.0092 - val_accuracy: 0.9561 - val_loss: 0.1161
# Epoch 19/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9649 - val_loss: 0.1151
# Epoch 20/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9561 - val_loss: 0.1347
# Epoch 21/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9649 - val_loss: 0.1115
# Epoch 22/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9561 - val_loss: 0.1456
# Epoch 23/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9649 - val_loss: 0.1331
# Epoch 24/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9649 - val_loss: 0.1205
# Epoch 25/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9561 - val_loss: 0.1614
# Epoch 26/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9649 - val_loss: 0.1407
# Epoch 27/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9561 - val_loss: 0.1530
# Epoch 28/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.9185e-04 - val_accuracy: 0.9561 - val_loss: 0.1539
# Epoch 29/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.0535e-04 - val_accuracy: 0.9561 - val_loss: 0.1592
# Epoch 30/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 4.5060e-04 - val_accuracy: 0.9561 - val_loss: 0.1606
# Epoch 31/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.6567e-04 - val_accuracy: 0.9561 - val_loss: 0.1621
# Epoch 32/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.3132e-04 - val_accuracy: 0.9561 - val_loss: 0.1656
# Epoch 33/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.4732e-04 - val_accuracy: 0.9561 - val_loss: 0.1673
# Epoch 34/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6455e-04 - val_accuracy: 0.9561 - val_loss: 0.1705
# Epoch 35/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.6579e-04 - val_accuracy: 0.9561 - val_loss: 0.1705
# Epoch 36/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.9451e-04 - val_accuracy: 0.9561 - val_loss: 0.1727
# Epoch 37/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.2952e-04 - val_accuracy: 0.9561 - val_loss: 0.1741
# Epoch 38/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.6620e-04 - val_accuracy: 0.9561 - val_loss: 0.1760
# Epoch 39/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.8192e-04 - val_accuracy: 0.9561 - val_loss: 0.1817
# Epoch 40/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.8549e-04 - val_accuracy: 0.9561 - val_loss: 0.1805
# Epoch 41/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.2027e-04 - val_accuracy: 0.9561 - val_loss: 0.1819
# Epoch 42/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.5013e-04 - val_accuracy: 0.9561 - val_loss: 0.1842
# Epoch 43/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0661e-04 - val_accuracy: 0.9561 - val_loss: 0.1852
# Epoch 44/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0828e-04 - val_accuracy: 0.9561 - val_loss: 0.1859
# Epoch 45/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.0269e-04 - val_accuracy: 0.9561 - val_loss: 0.1878
# Epoch 46/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3048e-04 - val_accuracy: 0.9561 - val_loss: 0.1894
# Epoch 47/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.3339e-04 - val_accuracy: 0.9561 - val_loss: 0.1892
# Epoch 48/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.9363e-05 - val_accuracy: 0.9561 - val_loss: 0.1920
# Epoch 49/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.7127e-04 - val_accuracy: 0.9561 - val_loss: 0.1936
# Epoch 50/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 8.8264e-05 - val_accuracy: 0.9561 - val_loss: 0.1963
# Epoch 51/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0785e-04 - val_accuracy: 0.9561 - val_loss: 0.1987
# Epoch 52/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.4862e-04 - val_accuracy: 0.9561 - val_loss: 0.1969
# Epoch 53/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.2075e-04 - val_accuracy: 0.9561 - val_loss: 0.1979
# Epoch 54/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.3316e-05 - val_accuracy: 0.9561 - val_loss: 0.1993
# Epoch 55/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.4023e-04 - val_accuracy: 0.9561 - val_loss: 0.2018
# Epoch 56/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.2705e-05 - val_accuracy: 0.9561 - val_loss: 0.2034
# Epoch 57/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 1.1733e-04 - val_accuracy: 0.9561 - val_loss: 0.2057
# Epoch 58/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.0303e-04 - val_accuracy: 0.9561 - val_loss: 0.2040
# Epoch 59/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.1934e-04 - val_accuracy: 0.9561 - val_loss: 0.2056
# Epoch 60/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.3823e-05 - val_accuracy: 0.9561 - val_loss: 0.2076
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Cancer MLP metrics: {'accuracy': 0.956140350877193, 'precision': 0.9855072463768116, 'recall': 0.9444444444444444, 'f1': 0.9645390070921985}
# Logistic: {'accuracy': 0.9824561403508771, 'precision': 0.9861111111111112, 'recall': 0.9861111111111112, 'f1': 0.9861111111111112}
# SVM: {'accuracy': 0.9824561403508771, 'precision': 0.9861111111111112, 'recall': 0.9861111111111112, 'f1': 0.9861111111111112}

# %% [markdown]
# Problem 3

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = y_train.flatten(); y_test = y_test.flatten()

x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0
x_train_flat = x_train.reshape((x_train.shape[0], -1))
x_test_flat = x_test.reshape((x_test.shape[0], -1))

USE_SUBSET = False
if USE_SUBSET:
    n_train = 20000; n_test = 5000
    x_train_flat = x_train_flat[:n_train]; y_train = y_train[:n_train]
    x_test_flat = x_test_flat[:n_test]; y_test = y_test[:n_test]

# 3a
model3a = models.Sequential([
    layers.Input(shape=(x_train_flat.shape[1],)),
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3a.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
start = time.time()
hist3a = model3a.fit(x_train_flat, y_train, validation_data=(x_test_flat, y_test), epochs=10, batch_size=128)
time_a = time.time()-start
print("3a time (s):", time_a)
plot_loss(hist3a, "CIFAR-10 MLP (1 hidden 512) - Loss")

# 3b
model3b = models.Sequential([
    layers.Input(shape=(x_train_flat.shape[1],)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3b.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 300 epochs, takes forever to run
EPOCHS_3B = 300
hist3b = model3b.fit(x_train_flat, y_train, validation_data=(x_test_flat, y_test), epochs=EPOCHS_3B, batch_size=128)
plot_loss(hist3b, "CIFAR-10 MLP (3 hidden layers) - Loss")

# 3c
# Not much over-fitting with 10 epochs
# A lot of over-fitting with 300 epochs
# Out:
# Epoch 1/10
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 16s 38ms/step - accuracy: 0.2693 - loss: 2.2164 - val_accuracy: 0.3836 - val_loss: 1.7439
# Epoch 2/10
#  81/391 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - accuracy: 0.3619 - loss: 1.7695
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-384068711.py in <cell line: 0>()
#      23 model3a.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#      24 start = time.time()
# ---> 25 hist3a = model3a.fit(x_train_flat, y_train, validation_data=(x_test_flat, y_test), epochs=10, batch_size=128)
#      26 time_a = time.time()-start
#      27 print("3a time (s):", time_a)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     218                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219             ):
# --> 220                 opt_outputs = multi_step_on_iterator(iterator)
#     221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
