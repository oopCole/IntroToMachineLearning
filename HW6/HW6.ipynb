# %% [markdown]
# <a href="https://colab.research.google.com/github/oopCole/IntroToMachineLearning/blob/main/HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.datasets import load_diabetes, load_breast_cancer

# %% [markdown]
# Problem 1

# %%
# diabetes dataset from my github
dataFrame = pd.read_csv('https://raw.githubusercontent.com/oopCole/IntroToMachineLearning/refs/heads/main/diabetes.csv')

print(dataFrame.head())
print(dataFrame.info())
print(dataFrame.isnull().sum())

xFeatures = dataFrame.drop('Outcome', axis=1)
yTarget = dataFrame['Outcome']

# 20/80 split
xTrain, xVal, yTrain, yVal = train_test_split(xFeatures, yTarget, test_size=0.2, random_state=42, stratify=yTarget)

scaler = StandardScaler()
xTrainScaled = scaler.fit_transform(xTrain)
xValScaled = scaler.transform(xVal)

# 4 hidden layers
neuralModel = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(xTrainScaled.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

neuralModel.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print(neuralModel.summary())

earlyStopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

historyObject = neuralModel.fit(
    xTrainScaled, yTrain,
    epochs=100,
    batch_size=32,
    validation_data=(xValScaled, yVal),
    callbacks=[earlyStopping],
    verbose=1
)

# plot
plt.figure(figsize=(9, 4))

plt.subplot(1, 2, 1)
plt.plot(historyObject.history['loss'], label='Training Loss')
plt.plot(historyObject.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(historyObject.history['accuracy'], label='Training Accuracy')
plt.plot(historyObject.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')
plt.grid(True)

plt.tight_layout()
plt.show()

# predictions
yPredProba = neuralModel.predict(xValScaled)
yPredNN = (yPredProba > 0.5).astype(int).flatten()

nnAccuracy = accuracy_score(yVal, yPredNN)
nnPrecision = precision_score(yVal, yPredNN)
nnRecall = recall_score(yVal, yPredNN)
nnF1 = f1_score(yVal, yPredNN)

print("Neural Network Performance:")
print(f"Accuracy: {nnAccuracy:.4f}")
print(f"Precision: {nnPrecision:.4f}")
print(f"Recall: {nnRecall:.4f}")
print(f"F1 Score: {nnF1:.4f}")

# train logistic
logisticModel = LogisticRegression(max_iter=1000, random_state=42)
logisticModel.fit(xTrainScaled, yTrain)
yPredLR = logisticModel.predict(xValScaled)

lrAccuracy = accuracy_score(yVal, yPredLR)
lrPrecision = precision_score(yVal, yPredLR)
lrRecall = recall_score(yVal, yPredLR)
lrF1 = f1_score(yVal, yPredLR)

print("\nLogistic Regression Performance:")
print(f"Accuracy: {lrAccuracy:.4f}")
print(f"Precision: {lrPrecision:.4f}")
print(f"Recall: {lrRecall:.4f}")
print(f"F1 Score: {lrF1:.4f}")

# train support
svmModel = SVC(kernel='rbf', random_state=42)
svmModel.fit(xTrainScaled, yTrain)
yPredSVM = svmModel.predict(xValScaled)

svmAccuracy = accuracy_score(yVal, yPredSVM)
svmPrecision = precision_score(yVal, yPredSVM)
svmRecall = recall_score(yVal, yPredSVM)
svmF1 = f1_score(yVal, yPredSVM)

print("\nSupport Vector Machine Performance:")
print(f"Accuracy: {svmAccuracy:.4f}")
print(f"Precision: {svmPrecision:.4f}")
print(f"Recall: {svmRecall:.4f}")
print(f"F1 Score: {svmF1:.4f}")

comparisonData = {
    'Model': ['Neural Network', 'Logistic Regression', 'SVM'],
    'Accuracy': [nnAccuracy, lrAccuracy, svmAccuracy],
    'Precision': [nnPrecision, lrPrecision, svmPrecision],
    'Recall': [nnRecall, lrRecall, svmRecall],
    'F1 Score': [nnF1, lrF1, svmF1]
}

comparisonDf = pd.DataFrame(comparisonData)
print("\nModel Comparison:")
print(comparisonDf.to_string(index=False))

# bar chart of each model
metricsToPlot = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
xPositions = np.arange(len(metricsToPlot))
barWidth = 0.25

plt.figure(figsize=(8, 4))
plt.bar(xPositions - barWidth, [nnAccuracy, nnPrecision, nnRecall, nnF1], barWidth, label='Neural Network')
plt.bar(xPositions, [lrAccuracy, lrPrecision, lrRecall, lrF1], barWidth, label='Logistic Regression')
plt.bar(xPositions + barWidth, [svmAccuracy, svmPrecision, svmRecall, svmF1], barWidth, label='SVM')

plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Model Performance Comparison')
plt.xticks(xPositions, metricsToPlot)
plt.legend()
plt.ylim([0, 1])
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,329 (13.00 KB)
#  Trainable params: 3,329 (13.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6243 - loss: 0.6726 - val_accuracy: 0.6883 - val_loss: 0.6444
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6616 - loss: 0.6530 - val_accuracy: 0.6753 - val_loss: 0.6122
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6268 - loss: 0.6172 - val_accuracy: 0.6688 - val_loss: 0.5835
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6908 - loss: 0.5579 - val_accuracy: 0.6623 - val_loss: 0.5595
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6712 - loss: 0.5423 - val_accuracy: 0.6883 - val_loss: 0.5474
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7389 - loss: 0.5159 - val_accuracy: 0.7403 - val_loss: 0.5366
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7272 - loss: 0.5410 - val_accuracy: 0.7338 - val_loss: 0.5297
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7442 - loss: 0.5125 - val_accuracy: 0.7532 - val_loss: 0.5230
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7749 - loss: 0.4972 - val_accuracy: 0.7532 - val_loss: 0.5150
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7536 - loss: 0.5318 - val_accuracy: 0.7338 - val_loss: 0.5103
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7450 - loss: 0.5062 - val_accuracy: 0.7532 - val_loss: 0.5067
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7373 - loss: 0.5285 - val_accuracy: 0.7273 - val_loss: 0.5043
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8010 - loss: 0.4678 - val_accuracy: 0.7338 - val_loss: 0.5031
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8058 - loss: 0.4379 - val_accuracy: 0.7403 - val_loss: 0.4998
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7682 - loss: 0.4503 - val_accuracy: 0.7403 - val_loss: 0.4963
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7744 - loss: 0.4570 - val_accuracy: 0.7338 - val_loss: 0.4943
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7922 - loss: 0.4306 - val_accuracy: 0.7403 - val_loss: 0.4972
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8003 - loss: 0.4497 - val_accuracy: 0.7403 - val_loss: 0.4954
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7640 - loss: 0.4675 - val_accuracy: 0.7338 - val_loss: 0.4952
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7775 - loss: 0.4634 - val_accuracy: 0.7338 - val_loss: 0.4961
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7589 - loss: 0.4718 - val_accuracy: 0.7208 - val_loss: 0.4939
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7982 - loss: 0.4324 - val_accuracy: 0.7338 - val_loss: 0.4927
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7969 - loss: 0.4417 - val_accuracy: 0.7273 - val_loss: 0.4967
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7896 - loss: 0.4350 - val_accuracy: 0.7208 - val_loss: 0.4986
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7694 - loss: 0.4851 - val_accuracy: 0.7208 - val_loss: 0.4970
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7964 - loss: 0.4286 - val_accuracy: 0.7208 - val_loss: 0.4987
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8192 - loss: 0.4411 - val_accuracy: 0.7273 - val_loss: 0.5012
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7922 - loss: 0.4474 - val_accuracy: 0.7273 - val_loss: 0.4997
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7904 - loss: 0.4235 - val_accuracy: 0.7338 - val_loss: 0.4990
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8064 - loss: 0.4583 - val_accuracy: 0.7403 - val_loss: 0.4989
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8031 - loss: 0.4682 - val_accuracy: 0.7273 - val_loss: 0.4982
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7974 - loss: 0.4344 - val_accuracy: 0.7208 - val_loss: 0.5021
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7811 - loss: 0.4480 - val_accuracy: 0.7338 - val_loss: 0.4998
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7981 - loss: 0.4404 - val_accuracy: 0.7143 - val_loss: 0.5031
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7745 - loss: 0.4650 - val_accuracy: 0.7403 - val_loss: 0.5015
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7922 - loss: 0.4513 - val_accuracy: 0.7403 - val_loss: 0.5055
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7969 - loss: 0.4433 - val_accuracy: 0.7273 - val_loss: 0.5061
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e815143eac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e815143eac0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Neural Network Performance:
# Accuracy: 0.7338
# Precision: 0.6140
# Recall: 0.6481
# F1 Score: 0.6306
#
# Logistic Regression Performance:
# Accuracy: 0.7143
# Precision: 0.6087
# Recall: 0.5185
# F1 Score: 0.5600
#
# Support Vector Machine Performance:
# Accuracy: 0.7532
# Precision: 0.6600
# Recall: 0.6111
# F1 Score: 0.6346
#
# Model Comparison:
#               Model  Accuracy  Precision   Recall  F1 Score
#      Neural Network  0.733766   0.614035 0.648148  0.630631
# Logistic Regression  0.714286   0.608696 0.518519  0.560000
#                 SVM  0.753247   0.660000 0.611111  0.634615

# %% [markdown]
# Problem 2

# %%
cancer = load_breast_cancer()

def metrics_from_preds(y_true, y_pred):
    return {
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred, zero_division=0),
        'recall': recall_score(y_true, y_pred, zero_division=0),
        'f1': f1_score(y_true, y_pred, zero_division=0)
    }

def plot_loss(history, title):
    plt.figure(figsize=(6,4))
    plt.plot(history.history['loss'], label='train loss')
    if 'val_loss' in history.history:
        plt.plot(history.history['val_loss'], label='val loss')
    plt.title(title)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

X_c, y_c = cancer.data, cancer.target
X_train_c, X_val_c, y_train_c, y_val_c = train_test_split(X_c, y_c, test_size=0.2, random_state=42, stratify=y_c)
scaler_c = StandardScaler().fit(X_train_c)
X_train_c_s = scaler_c.transform(X_train_c)
X_val_c_s = scaler_c.transform(X_val_c)

model_c = models.Sequential([
    layers.Input(shape=(X_train_c_s.shape[1],)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model_c.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist_c = model_c.fit(X_train_c_s, y_train_c, validation_data=(X_val_c_s, y_val_c), epochs=60, batch_size=16)
plot_loss(hist_c, "Breast Cancer - MLP Keras")
y_pred_c = (model_c.predict(X_val_c_s).ravel() >= 0.5).astype(int)

print("Cancer MLP metrics:", metrics_from_preds(y_val_c, y_pred_c))
print("Logistic:", metrics_from_preds(y_val_c, LogisticRegression(max_iter=5000).fit(X_train_c_s, y_train_c).predict(X_val_c_s)))
print("SVM:", metrics_from_preds(y_val_c, SVC().fit(X_train_c_s, y_train_c).predict(X_val_c_s)))
# Out:
# Epoch 1/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6107 - loss: 0.6581 - val_accuracy: 0.9035 - val_loss: 0.4233
# Epoch 2/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9748 - loss: 0.3359 - val_accuracy: 0.9474 - val_loss: 0.1816
# Epoch 3/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9718 - loss: 0.1213 - val_accuracy: 0.9649 - val_loss: 0.0996
# Epoch 4/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9829 - loss: 0.0707 - val_accuracy: 0.9561 - val_loss: 0.0910
# Epoch 5/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9804 - loss: 0.0705 - val_accuracy: 0.9649 - val_loss: 0.0844
# Epoch 6/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0392 - val_accuracy: 0.9561 - val_loss: 0.0842
# Epoch 7/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9968 - loss: 0.0208 - val_accuracy: 0.9474 - val_loss: 0.0914
# Epoch 8/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9884 - loss: 0.0500 - val_accuracy: 0.9737 - val_loss: 0.0709
# Epoch 9/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9968 - loss: 0.0211 - val_accuracy: 0.9474 - val_loss: 0.1031
# Epoch 10/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9988 - loss: 0.0231 - val_accuracy: 0.9561 - val_loss: 0.0813
# Epoch 11/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9963 - loss: 0.0188 - val_accuracy: 0.9561 - val_loss: 0.0973
# Epoch 12/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.0140 - val_accuracy: 0.9561 - val_loss: 0.0965
# Epoch 13/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 0.9649 - val_loss: 0.0810
# Epoch 14/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9949 - loss: 0.0149 - val_accuracy: 0.9649 - val_loss: 0.0972
# Epoch 15/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0202 - val_accuracy: 0.9649 - val_loss: 0.0880
# Epoch 16/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9955 - loss: 0.0093 - val_accuracy: 0.9561 - val_loss: 0.1055
# Epoch 17/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9934 - loss: 0.0131 - val_accuracy: 0.9649 - val_loss: 0.0989
# Epoch 18/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0082 - val_accuracy: 0.9649 - val_loss: 0.0990
# Epoch 19/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0045 - val_accuracy: 0.9649 - val_loss: 0.1237
# Epoch 20/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9973 - loss: 0.0079 - val_accuracy: 0.9737 - val_loss: 0.0851
# Epoch 21/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9935 - loss: 0.0119 - val_accuracy: 0.9649 - val_loss: 0.1236
# Epoch 22/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0079 - val_accuracy: 0.9649 - val_loss: 0.1183
# Epoch 23/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0043 - val_accuracy: 0.9649 - val_loss: 0.1231
# Epoch 24/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9971 - loss: 0.0049 - val_accuracy: 0.9649 - val_loss: 0.1291
# Epoch 25/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9649 - val_loss: 0.1282
# Epoch 26/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9649 - val_loss: 0.1285
# Epoch 27/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9649 - val_loss: 0.1305
# Epoch 28/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9561 - val_loss: 0.1447
# Epoch 29/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9649 - val_loss: 0.1346
# Epoch 30/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9649 - val_loss: 0.1377
# Epoch 31/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9649 - val_loss: 0.1401
# Epoch 32/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9649 - val_loss: 0.1418
# Epoch 33/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 7.2906e-04 - val_accuracy: 0.9649 - val_loss: 0.1431
# Epoch 34/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.6610e-04 - val_accuracy: 0.9649 - val_loss: 0.1500
# Epoch 35/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.1572e-04 - val_accuracy: 0.9649 - val_loss: 0.1527
# Epoch 36/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9649 - val_loss: 0.1497
# Epoch 37/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.7848e-04 - val_accuracy: 0.9649 - val_loss: 0.1514
# Epoch 38/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 4.9755e-04 - val_accuracy: 0.9649 - val_loss: 0.1525
# Epoch 39/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.3829e-04 - val_accuracy: 0.9649 - val_loss: 0.1581
# Epoch 40/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.2136e-04 - val_accuracy: 0.9649 - val_loss: 0.1606
# Epoch 41/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.5048e-04 - val_accuracy: 0.9649 - val_loss: 0.1593
# Epoch 42/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.6984e-04 - val_accuracy: 0.9561 - val_loss: 0.1606
# Epoch 43/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.3028e-04 - val_accuracy: 0.9649 - val_loss: 0.1655
# Epoch 44/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 3.9918e-04 - val_accuracy: 0.9561 - val_loss: 0.1635
# Epoch 45/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.2651e-04 - val_accuracy: 0.9561 - val_loss: 0.1677
# Epoch 46/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.3246e-04 - val_accuracy: 0.9561 - val_loss: 0.1682
# Epoch 47/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.3683e-04 - val_accuracy: 0.9561 - val_loss: 0.1707
# Epoch 48/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.3379e-04 - val_accuracy: 0.9561 - val_loss: 0.1767
# Epoch 49/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 2.1631e-04 - val_accuracy: 0.9561 - val_loss: 0.1799
# Epoch 50/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.4594e-04 - val_accuracy: 0.9561 - val_loss: 0.1807
# Epoch 51/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.7195e-04 - val_accuracy: 0.9561 - val_loss: 0.1806
# Epoch 52/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.3593e-04 - val_accuracy: 0.9561 - val_loss: 0.1832
# Epoch 53/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.7687e-04 - val_accuracy: 0.9561 - val_loss: 0.1836
# Epoch 54/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.6930e-04 - val_accuracy: 0.9561 - val_loss: 0.1865
# Epoch 55/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 9.1948e-05 - val_accuracy: 0.9561 - val_loss: 0.1869
# Epoch 56/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.2061e-04 - val_accuracy: 0.9561 - val_loss: 0.1912
# Epoch 57/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.0517e-05 - val_accuracy: 0.9561 - val_loss: 0.1907
# Epoch 58/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 8.7113e-05 - val_accuracy: 0.9561 - val_loss: 0.1907
# Epoch 59/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 1.1197e-04 - val_accuracy: 0.9561 - val_loss: 0.1912
# Epoch 60/60
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.7003e-05 - val_accuracy: 0.9561 - val_loss: 0.1935
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Cancer MLP metrics: {'accuracy': 0.956140350877193, 'precision': 0.9855072463768116, 'recall': 0.9444444444444444, 'f1': 0.9645390070921985}
# Logistic: {'accuracy': 0.9824561403508771, 'precision': 0.9861111111111112, 'recall': 0.9861111111111112, 'f1': 0.9861111111111112}
# SVM: {'accuracy': 0.9824561403508771, 'precision': 0.9861111111111112, 'recall': 0.9861111111111112, 'f1': 0.9861111111111112}

# %% [markdown]
# Problem 3

# %%
from tensorflow.keras.datasets import cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
y_train = y_train.flatten(); y_test = y_test.flatten()

x_train = x_train.astype('float32')/255.0
x_test = x_test.astype('float32')/255.0
x_train_flat = x_train.reshape((x_train.shape[0], -1))
x_test_flat = x_test.reshape((x_test.shape[0], -1))

USE_SUBSET = False
if USE_SUBSET:
    n_train = 20000; n_test = 5000
    x_train_flat = x_train_flat[:n_train]; y_train = y_train[:n_train]
    x_test_flat = x_test_flat[:n_test]; y_test = y_test[:n_test]

# 3a
model3a = models.Sequential([
    layers.Input(shape=(x_train_flat.shape[1],)),
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3a.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
start = time.time()
hist3a = model3a.fit(x_train_flat, y_train, validation_data=(x_test_flat, y_test), epochs=10, batch_size=128)
time_a = time.time()-start
print("3a time (s):", time_a)
plot_loss(hist3a, "CIFAR-10 MLP (1 hidden 512) - Loss")

# 3b
model3b = models.Sequential([
    layers.Input(shape=(x_train_flat.shape[1],)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model3b.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 300 epochs, takes forever to run
EPOCHS_3B = 300
hist3b = model3b.fit(x_train_flat, y_train, validation_data=(x_test_flat, y_test), epochs=EPOCHS_3B, batch_size=128)
plot_loss(hist3b, "CIFAR-10 MLP (3 hidden layers) - Loss")

# 3c
# Not much over-fitting with 10 epochs
# A lot of over-fitting with 300 epochs
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1681457997.py in <cell line: 0>()
#       1 from tensorflow.keras.datasets import cifar10
# ----> 2 (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#       3 y_train = y_train.flatten(); y_test = y_test.flatten()
#       4
#       5 x_train = x_train.astype('float32')/255.0
#
# /usr/local/lib/python3.12/dist-packages/keras/src/datasets/cifar10.py in load_data()
#      63     dirname = "cifar-10-batches-py-target"
#      64     origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 65     path = get_file(
#      66         fname=dirname,
#      67         origin=origin,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     337             archive_format = "tar"
#     338
# --> 339         status = extract_archive(
#     340             download_target, extraction_dir, archive_format
#     341         )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/file_utils.py in extract_archive(file_path, path, archive_format)
#     115                     else:
#     116                         # Tar archive, perhaps unsafe. Filter paths.
# --> 117                         archive.extractall(
#     118                             path, members=filter_safe_paths(archive)
#     119                         )
#
# /usr/lib/python3.12/tarfile.py in extractall(self, path, members, numeric_owner, filter)
#    2321                 # extracting contents can reset mtime.
#    2322                 directories.append(unfiltered)
# -> 2323             self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2324                               numeric_owner=numeric_owner,
#    2325                               filter_function=filter_function)
#
# /usr/lib/python3.12/tarfile.py in _extract_one(self, tarinfo, path, set_attrs, numeric_owner, filter_function)
#    2424
#    2425         try:
# -> 2426             self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2427                                  set_attrs=set_attrs,
#    2428                                  numeric_owner=numeric_owner,
#
# /usr/lib/python3.12/tarfile.py in _extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner, filter_function, extraction_root)
#    2513
#    2514         if tarinfo.isreg():
# -> 2515             self.makefile(tarinfo, targetpath)
#    2516         elif tarinfo.isdir():
#    2517             self.makedir(tarinfo, targetpath)
#
# /usr/lib/python3.12/tarfile.py in makefile(self, tarinfo, targetpath)
#    2570                 target.truncate()
#    2571             else:
# -> 2572                 copyfileobj(source, target, tarinfo.size, ReadError, bufsize)
#    2573
#    2574     def makeunknown(self, tarinfo, targetpath):
#
# /usr/lib/python3.12/tarfile.py in copyfileobj(src, dst, length, exception, bufsize)
#     249     blocks, remainder = divmod(length, bufsize)
#     250     for b in range(blocks):
# --> 251         buf = src.read(bufsize)
#     252         if len(buf) < bufsize:
#     253             raise exception("unexpected end of data")
#
# /usr/lib/python3.12/gzip.py in read(self, size)
#     336             import errno
#     337             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 338         return self._buffer.read(size)
#     339
#     340     def read1(self, size=-1):
#
# /usr/lib/python3.12/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# /usr/lib/python3.12/gzip.py in read(self, size)
#     552                 uncompress = self._decompressor.decompress(buf, size)
#     553             else:
# --> 554                 uncompress = self._decompressor.decompress(b"", size)
#     555
#     556             if self._decompressor.unused_data != b"":
#
# KeyboardInterrupt:
